# %%
import pandas as pd

# Load the CSV data into a pandas DataFrame
df = pd.read_csv('taxi_zones.csv')

# Display the DataFrame
print(df)
# Out:
#     Unnamed: 0  OBJECTID  Shape_Leng  \
# 0            4         4    0.043567
# 1           10        24    0.047000
# 2           13        12    0.036661
# 3           14        13    0.050281
# 4           43        41    0.052793
# ..         ...       ...         ...
# 63         270       244    0.080569
# 64         272       246    0.069467
# 65         275       249    0.036384
# 66         286       261    0.027120
# 67         287       262    0.049064
#
#                                              the_geom  Shape_Area  \
# 0   MULTIPOLYGON (((-73.97177410965318 40.72582128...    0.000112
# 1   MULTIPOLYGON (((-73.95953658899997 40.79871852...    0.000061
# 2   MULTIPOLYGON (((-74.01565756599994 40.70483308...    0.000042
# 3   MULTIPOLYGON (((-74.01244109299991 40.71905767...    0.000149
# 4   MULTIPOLYGON (((-73.94773985499985 40.80959972...    0.000143
# ..                                                ...         ...
# ...

# %%
# Check how many rows and columns this dataframe has
print("number of rows and columns:", df.shape)
# Out:
# number of rows and columns: (68, 6958)

# %%
sample_statement="The {} {} rows are: "
print(sample_statement.format('first',50))
df.head(50)
# Out:
# The first 50 rows are:
#     Unnamed: 0  OBJECTID  Shape_Leng  \
# 0            4         4    0.043567
# 1           10        24    0.047000
# 2           13        12    0.036661
# 3           14        13    0.050281
# 4           43        41    0.052793
# 5           44        45    0.045907
# 6           47        42    0.092709
# 7           48        43    0.099739
# 8           52        48    0.043747
# 9           54        50    0.055748
# 10          76        68    0.049337
# 11          81        79    0.042625
# 12          83        74    0.110291
# 13          87        75    0.087664
# 14          92        87    0.036902
# 15          96        88    0.035205
# 16          98        90    0.030759
# 17          99       125    0.049732
# 18         110       100    0.024813
# 19         113       103    0.014306
# 20         114       104    0.021221
# 21         115       105    0.077425
# 22         117       107    0.038041
# ...

# %%
# Load the taxi_zones csv file
df_zones = pd.read_csv('taxi_zones.csv')

# Calculate the frequency of each LocationID
location_id_counts = df_zones['LocationID'].value_counts()
print(location_id_counts)
# Out:
# 103    3
# 4      1
# 229    1
# 158    1
# 161    1
#       ..
# 137    1
# 141    1
# 142    1
# 152    1
# 262    1
# Name: LocationID, Length: 66, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plot the counts
location_id_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Frequency of each LocationID')
plt.xlabel('LocationID')
plt.ylabel('Frequency')
plt.show()

# %%
# Count the zones in Manhattan
manhattan_zones_counts = manhattan_zones['zone'].value_counts()

# Plot the counts
manhattan_zones_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Zones in Manhattan')
plt.xlabel('Zone')
plt.ylabel('Frequency')
plt.show()
